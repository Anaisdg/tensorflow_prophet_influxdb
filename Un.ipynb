# %%
import matplotlib.pyplot as plt
import numpy as np
import random
 
Fs = 816
f = 5
sample = 800
x = np.arange(sample)
noise = 0.0008*np.asarray(random.sample(range(0,1000),sample))
 
y = np.sin(2 * np.pi * f * x / Fs)+noise
plt.plot(x, y)
plt.xlabel('voltage(V)')
plt.ylabel('sample(n)')
plt.show()

# %%
import requests
url = "http://localhost:9999/api/v2/write"
params = {'org':'qwerty', 'bucket':'initial'}
data = {'baby'}
response = requests.request("POST", url, params=params, data=data, headers=headers1)
print(response.code)
# Out:
# /Users/anaisdotis-georgiou/anaconda3/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7d5a7127f7ca> in <module>()
#       3 params = {'org':'qwerty', 'bucket':'initial'}
#       4 data = {'baby'}
# ----> 5 response = requests.request("POST", url, params=params, data=data, headers=headers1)
#       6 print(response.code)
#
# NameError: name 'headers1' is not defined

# %%
y=[3,24,7,8]
x = range(1,len(y)+1)

# %%
print(x)
# Out:
# range(1, 5)

# %%
m = Prophet()
m.fit(df)
m = Prophet()
m.fit(df)
<fbprophet.forecaster.Prophet at 0x10c23d400>
Predictions are then made on a dataframe with a column ds containing the dates for which a prediction is to be made. You can get a suitable dataframe that extends into the future a specified number of days using the helper method Prophet.make_future_dataframe. By default it will also include the dates from the history, so we will see the model fit as well.

future = m.make_future_dataframe(periods=365)
future.tail()
ds
3265	2017-01-15
3266	2017-01-16
3267	2017-01-17
3268	2017-01-18
3269	2017-01-19
The predict method will assign each row in future a predicted value which it names yhat. If you pass in historical dates, it will provide an in-sample fit. The forecast object here is a new dataframe that includes a column yhat with the forecast, as well as columns for components and uncertainty intervals.

forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
ds	yhat	yhat_lower	yhat_upper
3265	2017-01-15	8.206497	7.527265	8.925798
3266	2017-01-16	8.531523	7.792681	9.251638
3267	2017-01-17	8.318930	7.568879	9.063248
3268	2017-01-18	8.151543	7.415740	8.821083
3269	2017-01-19	8.163477	7.394263	8.892524
You can plot the forecast by calling the Prophet.plot method and passing in your forecast dataframe.

fig1 = m.plot(forecast)
